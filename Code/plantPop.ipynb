# %%
## Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
from math import sin, cos, sqrt, atan2, radians
import warnings

# %%
plantPop = pd.read_csv('../Data/plantPop_noDuplicates.csv')

# %%
plantPop.head()
# Out:
#    Unnamed: 0    Zip        City State   Latitude  Longitude  \
# 0           0   5769   Salisbury    VT  43.914026  -73.10703
# 1           1   1085   Westfield    MA  42.133642  -72.75029
# 2           2   1340     Colrain    MA  42.673371  -72.73104
# 3           3  26035    Colliers    WV  40.352943  -80.55585
# 4           4  36279  Wellington    AL  33.862349  -85.89512
#
#    2010 Census Population  Distance from Arkansas Nuclear One, Unit 1  \
# 0                    1216                                 1964.516138
# 1                   41117                                 1926.478786
# 2                    1701                                 1945.702821
# 3                    2491                                 1245.246703
# 4                    2645                                  692.507354
#
#    Distance from Beaver Valley Power Station 1  \
# 0                                   703.791569
# 1                                   661.448479
# ...

# %%
onePlant = pd.DataFrame(plantPop['Distance from Arkansas Nuclear One, Unit 1'].copy())
onePlant.head()
# Out:
#    Distance from Arkansas Nuclear One, Unit 1
# 0                                 1964.516138
# 1                                 1926.478786
# 2                                 1945.702821
# 3                                 1245.246703
# 4                                  692.507354

# %%
onePlant.sort_values(by= 'Distance from Arkansas Nuclear One, Unit 1',  inplace=True)

# %%
onePlant.head()
# Out:
#        Distance from Arkansas Nuclear One, Unit 1
# 16495                                    6.513935
# 31050                                   10.355282
# 9999                                    11.197992
# 7511                                    11.592383
# 30417                                   12.768701

# %%
theEdges = np.arange(0, 500, 10)

# %%
x['Distance from Arkansas Nuclear One, Unit 1'] = pd.cut(onePlant['Distance from Arkansas Nuclear One, Unit 1'], bins=theEdges)

# %%
len(x)
# Out:
# 32877
