# %%
## Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
from math import sin, cos, sqrt, atan2, radians
import warnings

# %%
## Import API key
from api_keys import g_key
## configure the gmaps key
gmaps.configure(api_key=g_key)

# %%
binnedPop = pd.read_csv('../Data/binnedPop.csv')
binnedPop.head()
# Out:
#    Unnamed: 0  Distance from Arkansas Nuclear One, Unit 1  \
# 0           0                                        2850
# 1           1                                       64692
# 2           2                                       22898
# 3           3                                       20356
# 4           4                                       25134
#
#    Distance from Beaver Valley Power Station 1  \
# 0                                        12763
# 1                                       190311
# 2                                       194242
# 3                                       435755
# 4                                       724334
#
#    Distance from Braidwood Station 1  \
# 0                              21041
# 1                              36326
# 2                              41035
# 3                             245765
# 4                             279721
#
#    Distance from Browns Ferry Nuclear Plant 1  \
# ...

# %%
latLongPlants = pd.read_excel('../Data/LatLongPlants.xlsx')
latLongPlants.head()
# Out:
#                             Name          City State        Lat       Long  \
# 0   Arkansas Nuclear One, Unit 1        London    AR  35.330898 -93.247162
# 1   Arkansas Nuclear One, Unit 2        London    AR  35.330898 -93.247162
# 2  Beaver Valley Power Station 1  Shippingport    PA  40.629372 -80.421249
# 3  Beaver Valley Power Station 2  Shippingport    PA  40.629372 -80.421249
# 4            Braidwood Station 1    Braceville    IL  41.226929 -88.264282
#
#    Open  License Expires  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0  1974             2034         NaN         NaN         NaN
# 1  1974             2034         NaN         NaN         NaN
# 2  1976             2036         NaN         NaN         NaN
# 3  1976             2036         NaN         NaN         NaN
# 4  1987             2046         NaN         NaN         NaN
#
#                                      Website
# 0  https://www.nrc.gov/info-finder/reactors/
# 1                                        NaN
# ...

# %%
plantPop = pd.read_csv('../Data/plantPop_noDuplicates.csv')
plantPop.head(2)
# Out:
#    Unnamed: 0   Zip       City State   Latitude  Longitude  \
# 0           0  5769  Salisbury    VT  43.914026  -73.10703
# 1           1  1085  Westfield    MA  42.133642  -72.75029
#
#    2010 Census Population  Distance from Arkansas Nuclear One, Unit 1  \
# 0                    1216                                 1964.516138
# 1                   41117                                 1926.478786
#
#    Distance from Beaver Valley Power Station 1  \
# 0                                   703.791569
# 1                                   661.448479
#
#    Distance from Braidwood Station 1  ...  Distance from Sequoyah 1  \
# 0                        1275.062906  ...               1413.202932
# 1                        1290.960391  ...               1322.663768
#
#    Distance from South Texas 1  Distance from Summer  Distance from Surry 1  \
# 0                  2619.275755           1278.988498             816.682053
# ...

# %%
reactorLocations = latLongPlants[['Lat', 'Long']]
reactorLocations.head()
# Out:
#          Lat       Long
# 0  35.330898 -93.247162
# 1  35.330898 -93.247162
# 2  40.629372 -80.421249
# 3  40.629372 -80.421249
# 4  41.226929 -88.264282

# %%
cols = plantPop.columns
colsDF = pd.DataFrame(cols)
thePlantNames = colsDF.loc[7:len(cols)]
thePlantNames.head(3)
# Out:
#                                              0
# 7   Distance from Arkansas Nuclear One, Unit 1
# 8  Distance from Beaver Valley Power Station 1
# 9            Distance from Braidwood Station 1

# %%
# calculate max 2010 population 
def findMaxPopOfIncludedZips(plantName, df, distance):
    df.sort_values(by= [plantName],  inplace=True)
    nearPops = df[(onePlant[plantName] <= distance)]
    pops = nearPops['2010 Census Population'].values
    maxPop.append(max(pops))
    return maxPop

# %%
distance = 5000 
maxPop = []
for index, row in thePlantNames.iterrows():
    plantName = row[0]
    onePlant = pd.DataFrame(plantPop[[plantName, 'Latitude', 'Longitude', '2010 Census Population']])
    maxPop = findMaxPopOfIncludedZips(plantName, plantPop, distance)
    
finalMaxPop = float(max(maxPop))
# finalMaxPop.astype(float)
type(finalMaxPop)
# Out:
# <ipython-input-8-5f36bbb9fa78>:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   nearPops = df[(onePlant[plantName] <= distance)]
# float

# %%
def plotPopDensFromReactors(plantName, df, distance):
    df.sort_values(by= [plantName],  inplace=True)
    nearPops = df[(onePlant[plantName] <= distance)]
    locations = nearPops[["Latitude", "Longitude"]]
    pops = nearPops['2010 Census Population'].values
    heat_layer = gmaps.heatmap_layer(locations, weights=pops, dissipating=False, max_intensity=finalMaxPop, point_radius=.2)
    fig.add_layer(heat_layer)

# %%
# distance = 100
fig = gmaps.figure()
for index, row in thePlantNames.iterrows():
    plantName = row[0]
    onePlant = pd.DataFrame(plantPop[[plantName, 'Latitude', 'Longitude', '2010 Census Population']])
    plotPopDensFromReactors(plantName, onePlant, distance)

# %%
markerLayer = gmaps.symbol_layer(reactorLocations, fill_color='black', stroke_color='white', scale=4)
fig.add_layer(markerLayer)
# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
